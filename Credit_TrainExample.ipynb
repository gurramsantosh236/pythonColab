# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
credit_data=pd.read_csv("sample_data/credit_train.csv")
credit_data.head()
df=credit_data.describe()
df.T
# Out:
#                             count          mean           std          min  \
# Unnamed: 0                54740.0  49972.654238  28883.901426     1.000000
# ID                        54740.0  80589.730307  43325.852378  5634.000000
# Monthly_Inhand_Salary     54740.0   4205.106827   3186.265970   303.645417
# Num_Bank_Accounts         54740.0     16.634710    114.924728    -1.000000
# Num_Credit_Card           54740.0     22.909847    130.295385     0.000000
# Interest_Rate             54740.0     74.188071    473.022799     1.000000
# Delay_from_due_date       54740.0     21.054512     14.840879    -5.000000
# Num_Credit_Inquiries      54740.0     27.592218    192.130784     0.000000
# Outstanding_Debt          54740.0   1424.694102   1153.240584     0.230000
# Credit_Utilization_Ratio  54740.0     32.281263      5.111356    20.172942
# Total_EMI_per_month       54740.0   1411.066778   8305.102900     0.000000
# ...

# %%
credit_data.shape
# Out:
# (54740, 29)

# %%
credit_data=pd.read_csv("sample_data/credit_train.csv")
credit_data=credit_data.drop_duplicates()
credit_data.shape
# Out:
# (54740, 29)

# %%
credit_data.dropna(inplace=True)
credit_data.shape
# Out:
# (18968, 29)

# %%
credit_data=pd.read_csv("sample_data/credit_train.csv")
credit_data.head()
# Out:
#    Unnamed: 0      ID Customer_ID   Month       Name Age          SSN  \
# 0       46184   74905  CUS_0xbbda  August  le Stevem  50  598-28-8368
# 1       63927  101520  CUS_0x1e51    July   Raymondl  32  887-23-0031
# 2       65974  104591  CUS_0x1765    June     Harryw  32  966-30-5287
# 3       68006  107639  CUS_0x751c    June   Jessican  19  220-63-1416
# 4       84461  132322  CUS_0x1c59     May       Dayz  41  277-13-7658
#
#      Occupation Annual_Income  Monthly_Inhand_Salary  ...  Credit_Mix  \
# 0       Manager      72099.14            5842.350694  ...        Good
# 1  Entrepreneur      17443.94            1714.661667  ...         Bad
# 2       _______     15186.175            1527.514583  ...    Standard
# 3    Accountant     177696.92           15090.076667  ...        Good
# 4        Doctor     19188.055            1358.004583  ...           _
#
#    Outstanding_Debt  Credit_Utilization_Ratio      Credit_History_Age  \
# ...

# %%
sns.relplot(x="Annual_Income",y="Age",hue="Age",data=credit_data)
