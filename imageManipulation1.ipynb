# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np
import pandas as pd
from scipy import ndimage
import imageio as im
import matplotlib.pyplot as plt

# %%
img_array=im.imread('sample_data/koala.png')
# Out:
# /tmp/ipython-input-2191087758.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_array=im.imread('sample_data/koala.png')

# %%
print(x.shape)
# Out:
# (854, 1280, 3)

# %%
print(img_array)
# Out:
# [[[ 45  36  31]
#   [ 45  36  31]
#   [ 45  36  31]
#   ...
#   [ 88  73  60]
#   [ 82  69  58]
#   [ 81  70  61]]
#
#  [[ 45  36  31]
#   [ 46  36  32]
#   [ 45  36  31]
#   ...
#   [ 82  67  57]
#   [ 76  66  56]
#   [ 80  69  61]]
#
#  [[ 46  37  32]
#   [ 46  36  32]
#   [ 46  36  32]
#   ...
#   [ 82  67  58]
#   [ 84  71  60]
#   [ 79  70  62]]
#
#  ...
#
#  [[119 111 118]
#   [120 111 118]
#   [120 111 119]
#   ...
#   [155 156 156]
#   [156 155 153]
#   [164 163 159]]
#
#  [[120 112 119]
#   [120 112 119]
#   [120 113 120]
#   ...
#   [151 153 154]
#   [154 152 150]
#   [161 159 155]]
#
#  [[121 114 120]
#   [122 114 121]
#   [121 114 121]
#   ...
#   [146 147 147]
#   [151 150 149]
#   [156 155 152]]]

# %%
plt.imshow(img_array)

# %%
x1,x2=np.array_split(img_array,2,axis=1)
#plt.imshow(x1)
#plt.imshow(x2)
img_merged=np.concatenate((x2,x1),axis=1)
plt.imshow(img_merged)

# %%
# Assuming you have two image arrays to merge, for example, the split_img from the previous step
# merged_img = np.concatenate((split_img[0], split_img[1]), axis=0)

# If you split vertically, you would concatenate along axis=1
# merged_img = np.concatenate((split_img[0], split_img[1]), axis=1)

# For demonstration purposes, let's concatenate the x1 and x2 from cell zzTFr7_6RvGP
merged_img = np.concatenate((x1, x2), axis=1)

plt.imshow(merged_img)
plt.title("Merged image")
plt.show()
