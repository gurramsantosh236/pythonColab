# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
telecomm_data2=pd.read_csv('sample_data/Telcom_Customer_Churn2.csv')
telecomm_data2.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
telecomm_data2['Churn'] = telecomm_data2['Churn'].astype(int)
display(telecomm_data2.head())
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
telecomm_data2.describe().T
# Out:
#                          count        mean        std     min       25%  \
# Account length          2666.0  100.620405  39.563974    1.00   73.0000
# Area code               2666.0  437.438860  42.521018  408.00  408.0000
# Number vmail messages   2666.0    8.021755  13.612277    0.00    0.0000
# Total day minutes       2666.0  179.481620  54.210350    0.00  143.4000
# Total day calls         2666.0  100.310203  19.988162    0.00   87.0000
# Total day charge        2666.0   30.512404   9.215733    0.00   24.3800
# Total eve minutes       2666.0  200.386159  50.951515    0.00  165.3000
# Total eve calls         2666.0  100.023631  20.161445    0.00   87.0000
# Total eve charge        2666.0   17.033072   4.330864    0.00   14.0500
# Total night minutes     2666.0  201.168942  50.780323   43.70  166.9250
# Total night calls       2666.0  100.106152  19.418459   33.00   87.0000
# Total night charge      2666.0    9.052689   2.285120    1.97    7.5125
# ...

# %%
sns.catplot(y='Number vmail messages', kind='violin', data=telecomm_data2,aspect=2)

# %%
sns.catplot(x='Customer service calls', kind='violin', data=telecomm_data2,aspect=2)
