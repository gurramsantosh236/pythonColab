# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
data = {
    'Student': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
    'Math':    [88, 78, 95, 60, 55, 62, 80, 90, 58, 85],
    'Science': [92, 85, 96, 65, 58, 60, 83, 91, 59, 87]
}

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#   Student  Math  Science
# 0       A    88       92
# 1       B    78       85
# 2       C    95       96
# 3       D    60       65
# 4       E    55       58

# %%
X = df[['Math','Science']]
print(X)
# Out:
#    Math  Science
# 0    88       92
# 1    78       85
# 2    95       96
# 3    60       65
# 4    55       58
# 5    62       60
# 6    80       83
# 7    90       91
# 8    58       59
# 9    85       87

# %%
#Apply Kmeans++ clustering Alg
model = KMeans(n_clusters=2 , init='k-means++' , random_state= 42)
df['Cluster']= model.fit_predict(X)

# %%
df
# Out:
#   Student  Math  Science  Cluster
# 0       A    88       92        1
# 1       B    78       85        1
# 2       C    95       96        1
# 3       D    60       65        0
# 4       E    55       58        0
# 5       F    62       60        0
# 6       G    80       83        1
# 7       H    90       91        1
# 8       I    58       59        0
# 9       J    85       87        1

# %%
plt.scatter(df['Math'], df['Science'], c=df['Cluster'], cmap = 'viridis')
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], c='red', marker = 'X')
plt.xlabel('Math Score')
plt.ylabel('Science Score')
plt.title('K-Means++ Clustering of Students')
plt.grid(True)
plt.show()

# %%
print("Kmeans iterations", model.n_iter_)
# Out:
# Kmeans iterations 2

# %%
# K means
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Static dataset
data = {
    'Student': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
    'Math':    [88, 78, 95, 60, 55, 62, 80, 90, 58, 85],
    'Science': [92, 85, 96, 65, 58, 60, 83, 91, 59, 87]
}

df = pd.DataFrame(data)
X = df[['Math', 'Science']]

# Apply KMeans clustering
model1 = KMeans(n_clusters=2, random_state=42)
df['Cluster'] = model1.fit_predict(X)

# Plot clusters
plt.scatter(df['Math'], df['Science'], c=df['Cluster'], cmap='viridis', s=100)
plt.scatter(model1.cluster_centers_[:, 0], model.cluster_centers_[:, 1], c='red', marker='X', s=200)
plt.xlabel('Math Score')
plt.ylabel('Science Score')
plt.title('K-Means Clustering of Students')
plt.grid(True)
plt.show()

# %%
print("Kmeans iterations", model1.n_iter_)
# Out:
# Kmeans iterations 2

# %%
print("Kmeans++ iterations", model.n_iter_)
# Out:
# Kmeans++ iterations 2

# %%
#dbscan
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# Sample dataset
data = {
    'X': [1, 2, 2, 8, 8, 25, 25, 26, 27, 100],
    'Y': [2, 2, 3, 8, 9, 80, 81, 80, 82, 100]
}
df = pd.DataFrame(data)

# Apply DBSCAN
model = DBSCAN(eps=3, min_samples=2)
df['Cluster'] = model.fit_predict(df[['X', 'Y']])

# Plot
plt.scatter(df['X'], df['Y'], c=df['Cluster'], cmap='Set1', s=100)
plt.title("DBSCAN Clustering")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()
