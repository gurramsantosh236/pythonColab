# %%
import pandas as pd
import numpy as np

# %%
dict1 = {
    "name":['harry','rohan','Radha','shubh'],
    "marks":[92,34,24,17],
    "city":['rampur','kolkata','bareilly','antarctica'],
    "Gender": ['M','M','F','M']
}

# %%
df1=pd.DataFrame(dict1)
print(df1)
print(type(df1))
# Out:
#     name  marks        city Gender
# 0  harry     92      rampur      M
# 1  rohan     34     kolkata      M
# 2  Radha     24    bareilly      F
# 3  shubh     17  antarctica      M
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# * 1.Display the first 3rows of dataset*

# %%
df1.head(3)
# Out:
#     name  marks      city Gender
# 0  harry     92    rampur      M
# 1  rohan     34   kolkata      M
# 2  Radha     24  bareilly      F

# %% [markdown]
# * 2.Display the last 3rows of dataset*

# %%
df1.tail(3)
# Out:
#     name  marks        city Gender
# 1  rohan     34     kolkata      M
# 2  Radha     24    bareilly      F
# 3  shubh     17  antarctica      M

# %%
df1.describe() # only numerical coulmn will be considered
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
df1.describe(include='all') # all columns will be considered
# Out:
#          name     marks    city Gender
# count       4   4.00000       4      4
# unique      4       NaN       4      2
# top     harry       NaN  rampur      M
# freq        1       NaN       1      3
# mean      NaN  41.75000     NaN    NaN
# std       NaN  34.21866     NaN    NaN
# min       NaN  17.00000     NaN    NaN
# 25%       NaN  22.25000     NaN    NaN
# 50%       NaN  29.00000     NaN    NaN
# 75%       NaN  48.50000     NaN    NaN
# max       NaN  92.00000     NaN    NaN

# %% [markdown]
# * Find the unique values from Gender*

# %%
df1['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df1['Gender'].nunique()
# Out:
# 2

# %%
df1['Gender'].value_counts()
# Out:
# Gender
# M    3
# F    1
# Name: count, dtype: int64

# %%
df1
# Out:
#     name  marks        city Gender
# 0  harry     92      rampur      M
# 1  rohan     34     kolkata      M
# 2  Radha     24    bareilly      F
# 3  shubh     17  antarctica      M

# %%
df1[df1['marks']>=90]
# Out:
#     name  marks    city Gender
# 0  harry     92  rampur      M

# %%
df1[(df1['marks']>=90) & (df1['marks']<=100)] # students score between 90 to 100
# Out:
#     name  marks    city Gender
# 0  harry     92  rampur      M

# %%
len(df1[(df1['marks']>=90) & (df1['marks']<=100)]) # number of students scored between 90 to 100
# Out:
# 1

# %%
print(df1['marks'].mean())
# Out:
# 41.75
