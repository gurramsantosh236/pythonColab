# %% [markdown]
# <a href="https://colab.research.google.com/github/gurramsantosh236/pythonColab/blob/main/CreateModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('sample_data/taxi.csv')
df.head(5)
# Out:
#    Priceperweek  Population  Monthlyincome  Averageparkingpermonth  \
# 0            15     1800000           5800                      50
# 1            15     1790000           6200                      50
# 2            15     1780000           6400                      60
# 3            25     1778000           6500                      60
# 4            25     1750000           6550                      60
#
#    Numberofweeklyriders
# 0                192000
# 1                190400
# 2                191200
# 3                177600
# 4                176800

# %%
df_cleaned=df.drop_duplicates()
df=df_cleaned.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Priceperweek            27 non-null     int64
#  1   Population              27 non-null     int64
#  2   Monthlyincome           27 non-null     int64
#  3   Averageparkingpermonth  27 non-null     int64
#  4   Numberofweeklyriders    27 non-null     int64
# dtypes: int64(5)
# memory usage: 1.2 KB

# %%
from sklearn.model_selection import train_test_split
x=df.drop('Numberofweeklyriders',axis=1)
y=df['Numberofweeklyriders']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.Shape)
#print(x_test.Shape)
print(y_train.Shape)
#print(y_test.Shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-825320146.py in <cell line: 0>()
#       3 y=df['Numberofweeklyriders']
#       4 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
# ----> 5 print(x_train.Shape)
#       6 #print(x_test.Shape)
#       7 print(y_train.Shape)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'Shape'
